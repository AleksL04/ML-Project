# %%
# %%capture
# !pip install --upgrade gensim
# !gdown --folder 1rl_TJMHtcP-S0fTHNUpr9oi8Ndz2Y5z4 -O project_data
# !gdown --folder 1RmC_We2lfsJontwrxlc4dzqEY_mNy-UW -O word2vec_model

# %%
# !git clone https://github.com/AleksL04/ML-Project.git
# Out:
# Cloning into 'ML-Project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# Receiving objects: 100% (3/3), 9.71 KiB | 9.71 MiB/s, done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)

# %%
# %cd ML-Project
# Out:
# /content/ML-Project

# %%
ls -l
# Out:
# total 80
# -rw-r--r-- 1 root root 80098 Dec 10 20:57 Ensemble_Models.ipynb

# %%
import re
import pandas as pd
import numpy as np
import tensorflow as tf
import spacy
from gensim.models import KeyedVectors
from tensorflow.keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional, Masking
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics.pairwise import cosine_distances

# %%
#import gensim.downloader as api
#model = api.load('glove-wiki-gigaword-100')
#save_path = '/content/drive/MyDrive/glove-wiki-gigaword-100.vectors'
#model.save(save_path)

# %%
train_df = pd.read_csv('project_data/train.csv')
valid_df = pd.read_csv('project_data/valid.csv')
test_df = pd.read_csv('project_data/test.csv')

# %%
train_df.head()
#
# Out:
#                                                 text  label
# 0  states slow to shut down weak teacher educatio...      0
# 1    drone places fresh kill on steps of white house      1
# 2  report: majority of instances of people gettin...      1
# 3  sole remaining lung filled with rich, satisfyi...      1
# 4                       the gop's stockholm syndrome      0

# %%
model_path = 'word2vec_model/glove-wiki-gigaword-100.vectors'
word2vec_dict = KeyedVectors.load(model_path)

# %%
nlp = spacy.load("en_core_web_sm", disable=["tagger", "parser", "ner", "lemmatizer"])

# %%
def process_df(df, nlp):
    df['text'] = df['text'].str.lower()
    tokens_list = []
    for doc in nlp.pipe(df['text'].astype(str), batch_size=1000):
        tokens_list.append([token.text for token in doc if not token.is_space])

    df['text_split'] = tokens_list
    return df

def add_embedding(df, word2vec_dict):
    np.random.seed(42)
    random_vec = np.random.rand(100)*2-1

    embedding_list = []
    for tokens in df['text_split']:
        embedding = []
        for token in tokens:
            if token in word2vec_dict:
                embedding.append(word2vec_dict[token])
            else:
                embedding.append(random_vec)
        embedding_list.append(embedding)
    df['embedding'] = embedding_list
    return df

def prepare_X_y(df, max_len=50, vector_size=100):
    # Initialize a 3D matrix of zeros: (Num_Samples, Max_Time_Steps, Features)
    X = np.zeros((len(df), max_len, vector_size))

    # Fill the matrix
    for i, seq in enumerate(df['embedding']):
        # Truncate if longer than max_len
        length = min(len(seq), max_len)
        if length > 0:
            # Assign the sequence to the matrix (automatic padding at the end)
            X[i, :length, :] = np.array(seq)[:length]
    y = df['label'].values
    return X, y

# %%
train_clean = process_df(train_df, nlp)
valid_clean = process_df(valid_df, nlp)
test_clean = process_df(test_df, nlp)

# %%
train_clean = add_embedding(train_clean, word2vec_dict)
valid_clean = add_embedding(valid_clean, word2vec_dict)
test_clean = add_embedding(test_clean, word2vec_dict)

# %%
train_clean.head()
# Out:
#                                                 text  label  \
# 0  states slow to shut down weak teacher educatio...      0
# 1    drone places fresh kill on steps of white house      1
# 2  report: majority of instances of people gettin...      1
# 3  sole remaining lung filled with rich, satisfyi...      1
# 4                       the gop's stockholm syndrome      0
#
#                                           text_split  \
# 0  [states, slow, to, shut, down, weak, teacher, ...
# 1  [drone, places, fresh, kill, on, steps, of, wh...
# 2  [report, :, majority, of, instances, of, peopl...
# 3  [sole, remaining, lung, filled, with, rich, ,,...
# 4                [the, gop, 's, stockholm, syndrome]
#
#                                            embedding
# 0  [[0.13815, 0.45166, 0.93858, 0.055307, 0.70642...
# 1  [[-0.89403, 0.29261, 0.35079, 0.23718, -0.2033...
# 2  [[-0.59537, -0.32836, 0.58577, -0.74072, -0.09...
# 3  [[0.29567, -0.95131, 0.26483, -0.014256, 0.356...
# 4  [[-0.038194, -0.24487, 0.72812, -0.39961, 0.08...

# %%
MAX_LEN = 50
VECTOR_SIZE = 100
X_train, y_train = prepare_X_y(train_clean, MAX_LEN, VECTOR_SIZE)
X_valid, y_valid = prepare_X_y(valid_clean, MAX_LEN, VECTOR_SIZE)
X_test, y_test   = prepare_X_y(test_clean, MAX_LEN, VECTOR_SIZE)

# %%
from tensorflow.keras.layers import GlobalMaxPooling1D

# %%
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout, GlobalMaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

model = Sequential()

model.add(Bidirectional(LSTM(64, return_sequences=True, dropout=0.2)))

model.add(GlobalMaxPooling1D())

model.add(Dense(16, activation='relu')) # Intermediate dense layer
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 5. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=1, min_lr=1e-5)
]

# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_valid, y_valid),
#     epochs=20, # Increased epochs because we have EarlyStopping
#     batch_size=32,
#     callbacks=callbacks
# )

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8928 - loss: 0.2253
# Test Accuracy: 0.8996

# %%
# Train your first model as usual
history1 = model.fit(X_train, y_train, epochs=20, batch_size=32, verbose=0, validation_data=(X_valid, y_valid), callbacks=callbacks)
print("Model 1 Trained.")
# Out:
# Model 1 Trained.

# %%
import numpy as np

# 1. Get predictions (returns shape (N, 1))
train_preds = model.predict(X_train)

# 2. Force both to be flat 1D arrays
# This prevents the massive grid creation
y_train_flat = y_train.flatten() if hasattr(y_train, 'flatten') else np.array(y_train).flatten()
preds_flat = train_preds.flatten()

# 3. Calculate Error safely
errors = np.abs(y_train_flat - preds_flat)

# 4. Create Weights
sample_weights = 1.0 + (errors * 10.0)

print(f"Weights shape: {sample_weights.shape}") # Should now be (21464,)
# Out:
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# Weights shape: (21464,)

# %%
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D

# Let's use a slightly different architecture (CNN) for diversity
# CNNs look at local patterns, LSTMs look at sequences. They complement each other.
model2 = Sequential()
model2.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model2.add(GlobalMaxPooling1D())
model2.add(Dense(8, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(1, activation='sigmoid'))

model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train Model 2 with the calculated weights
history2 = model2.fit(
    X_train,
    y_train,
    sample_weight=sample_weights, # <--- THIS IS THE KEY
    validation_data=(X_valid, y_valid),
    epochs=20,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4794 - loss: 1.4313 - val_accuracy: 0.4986 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 2/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5371 - loss: 1.3939 - val_accuracy: 0.6648 - val_loss: 0.6198 - learning_rate: 0.0010
# Epoch 3/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6171 - loss: 1.3600 - val_accuracy: 0.8268 - val_loss: 0.5502 - learning_rate: 0.0010
# Epoch 4/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7053 - loss: 1.2620 - val_accuracy: 0.7584 - val_loss: 0.5432 - learning_rate: 0.0010
# Epoch 5/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7194 - loss: 1.1950 - val_accuracy: 0.8226 - val_loss: 0.4554 - learning_rate: 0.0010
# Epoch 6/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7564 - loss: 1.1105 - val_accuracy: 0.8156 - val_loss: 0.4214 - learning_rate: 0.0010
# Epoch 7/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8006 - loss: 1.0251 - val_accuracy: 0.8240 - val_loss: 0.4230 - learning_rate: 0.0010
# Epoch 8/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8355 - loss: 0.8536 - val_accuracy: 0.8394 - val_loss: 0.3969 - learning_rate: 2.0000e-04
# Epoch 9/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8439 - loss: 0.8009 - val_accuracy: 0.8324 - val_loss: 0.3945 - learning_rate: 2.0000e-04
# Epoch 10/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8541 - loss: 0.7339 - val_accuracy: 0.8408 - val_loss: 0.3976 - learning_rate: 2.0000e-04
# Epoch 11/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8658 - loss: 0.7056 - val_accuracy: 0.8310 - val_loss: 0.3902 - learning_rate: 4.0000e-05
# Epoch 12/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8642 - loss: 0.7104 - val_accuracy: 0.8324 - val_loss: 0.3888 - learning_rate: 4.0000e-05
# Epoch 13/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8656 - loss: 0.6857 - val_accuracy: 0.8324 - val_loss: 0.3910 - learning_rate: 4.0000e-05
# Epoch 14/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8675 - loss: 0.6742 - val_accuracy: 0.8324 - val_loss: 0.3907 - learning_rate: 1.0000e-05
# Epoch 15/20
# 671/671 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8685 - loss: 0.6570 - val_accuracy: 0.8366 - val_loss: 0.3920 - learning_rate: 1.0000e-05

# %%
import numpy as np

# 1. Get predictions from both models on VALIDATION data
# These are inputs for the meta-learner
val_pred1 = model.predict(X_valid)
val_pred2 = model2.predict(X_valid)

# 2. Stack them side-by-side
# Result shape: (num_valid_samples, 2)
# Row 1 example: [0.98, 0.45] (Model 1 was confident, Model 2 wasn't)
X_meta_train = np.column_stack((val_pred1, val_pred2))

# The target is the original validation labels
y_meta_train = y_valid
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
# A very simple "Blender" model
meta_model = Sequential()

# Input dim is 2 because we have 2 models feeding into it
meta_model.add(Dense(4,input_dim=2, activation='relu'))
meta_model.add(Dense(1, activation='sigmoid'))

# Compile
meta_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train on the outputs of the previous models
meta_model.fit(X_meta_train, y_meta_train, epochs=100, batch_size=32, verbose=1, callbacks=callbacks)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4923 - loss: 0.6905 - learning_rate: 0.0010
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5049 - loss: 0.6833 - learning_rate: 0.0010
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5400 - loss: 0.6777 - learning_rate: 0.0010
# Epoch 4/100
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5607 - loss: 0.6730 - learning_rate: 0.0010
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6000 - loss: 0.6696 - learning_rate: 0.0010
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6310 - loss: 0.6688 - learning_rate: 0.0010
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6569 - loss: 0.6644 - learning_rate: 0.0010
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6745 - loss: 0.6568 - learning_rate: 0.0010
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7170 - loss: 0.6520 - learning_rate: 0.0010
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7363 - loss: 0.6472 - learning_rate: 0.0010
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7494 - loss: 0.6406 - learning_rate: 0.0010
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7735 - loss: 0.6389 - learning_rate: 0.0010
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8149 - loss: 0.6258 - learning_rate: 0.0010
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8240 - loss: 0.6231 - learning_rate: 0.0010
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8505 - loss: 0.6118 - learning_rate: 0.0010
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8506 - loss: 0.6032 - learning_rate: 0.0010
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8704 - loss: 0.5953 - learning_rate: 0.0010
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8847 - loss: 0.5834 - learning_rate: 0.0010
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8813 - loss: 0.5698 - learning_rate: 0.0010
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8819 - loss: 0.5588 - learning_rate: 0.0010
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8962 - loss: 0.5447 - learning_rate: 0.0010
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8939 - loss: 0.5293 - learning_rate: 0.0010
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8956 - loss: 0.5154 - learning_rate: 0.0010
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8958 - loss: 0.5068 - learning_rate: 0.0010
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8948 - loss: 0.4976 - learning_rate: 0.0010
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8923 - loss: 0.4865 - learning_rate: 0.0010
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8764 - loss: 0.4834 - learning_rate: 0.0010
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8821 - loss: 0.4655 - learning_rate: 0.0010
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9022 - loss: 0.4459 - learning_rate: 0.0010
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9020 - loss: 0.4433 - learning_rate: 0.0010
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8932 - loss: 0.4382 - learning_rate: 0.0010
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8901 - loss: 0.4170 - learning_rate: 0.0010
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8755 - loss: 0.4329 - learning_rate: 0.0010
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8978 - loss: 0.4043 - learning_rate: 0.0010
# Epoch 35/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8868 - loss: 0.3954 - learning_rate: 0.0010
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8827 - loss: 0.4004 - learning_rate: 0.0010
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8886 - loss: 0.3820 - learning_rate: 0.0010
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9073 - loss: 0.3630 - learning_rate: 0.0010
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8973 - loss: 0.3615 - learning_rate: 0.0010
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8909 - loss: 0.3599 - learning_rate: 0.0010
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8965 - loss: 0.3538 - learning_rate: 0.0010
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8769 - loss: 0.3685 - learning_rate: 0.0010
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8956 - loss: 0.3406 - learning_rate: 0.0010
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8972 - loss: 0.3390 - learning_rate: 0.0010
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8966 - loss: 0.3285 - learning_rate: 0.0010
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8933 - loss: 0.3315 - learning_rate: 0.0010
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8891 - loss: 0.3263 - learning_rate: 0.0010
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8892 - loss: 0.3281 - learning_rate: 0.0010
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8923 - loss: 0.3203 - learning_rate: 0.0010
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8853 - loss: 0.3196 - learning_rate: 0.0010
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8788 - loss: 0.3392 - learning_rate: 0.0010
# Epoch 52/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9126 - loss: 0.2847 - learning_rate: 0.0010
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8868 - loss: 0.3145 - learning_rate: 0.0010
# Epoch 54/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8785 - loss: 0.3229 - learning_rate: 0.0010
# Epoch 55/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8964 - loss: 0.3007 - learning_rate: 0.0010
# Epoch 56/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8740 - loss: 0.3109 - learning_rate: 0.0010
# Epoch 57/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8842 - loss: 0.2984 - learning_rate: 0.0010
# Epoch 58/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8948 - loss: 0.3035 - learning_rate: 0.0010
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8907 - loss: 0.2947 - learning_rate: 0.0010
# Epoch 60/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8980 - loss: 0.2947 - learning_rate: 0.0010
# Epoch 61/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8781 - loss: 0.3205 - learning_rate: 0.0010
# Epoch 62/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8776 - loss: 0.3070 - learning_rate: 0.0010
# Epoch 63/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8987 - loss: 0.2794 - learning_rate: 0.0010
# Epoch 64/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9047 - loss: 0.2758 - learning_rate: 0.0010
# Epoch 65/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9010 - loss: 0.2747 - learning_rate: 0.0010
# Epoch 66/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8846 - loss: 0.2937 - learning_rate: 0.0010
# Epoch 67/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8853 - loss: 0.2931 - learning_rate: 0.0010
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8873 - loss: 0.2841 - learning_rate: 0.0010
# Epoch 69/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9039 - loss: 0.2761 - learning_rate: 0.0010
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8897 - loss: 0.2798 - learning_rate: 0.0010
# Epoch 71/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8983 - loss: 0.2746 - learning_rate: 0.0010
# Epoch 72/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8795 - loss: 0.3012 - learning_rate: 0.0010
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8819 - loss: 0.2931 - learning_rate: 0.0010
# Epoch 74/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8946 - loss: 0.2709 - learning_rate: 0.0010
# Epoch 75/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9012 - loss: 0.2629 - learning_rate: 0.0010
# Epoch 76/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8935 - loss: 0.2698 - learning_rate: 0.0010
# Epoch 77/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8789 - loss: 0.2919 - learning_rate: 0.0010
# Epoch 78/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8972 - loss: 0.2672 - learning_rate: 0.0010
# Epoch 79/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8799 - loss: 0.2899 - learning_rate: 0.0010
# Epoch 80/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8839 - loss: 0.2792 - learning_rate: 0.0010
# Epoch 81/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8878 - loss: 0.2650 - learning_rate: 0.0010
# Epoch 82/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8926 - loss: 0.2677 - learning_rate: 0.0010
# Epoch 83/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8780 - loss: 0.2850 - learning_rate: 0.0010
# Epoch 84/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8830 - loss: 0.2765 - learning_rate: 0.0010
# Epoch 85/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8944 - loss: 0.2740 - learning_rate: 0.0010
# Epoch 86/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8948 - loss: 0.2750 - learning_rate: 0.0010
# Epoch 87/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9073 - loss: 0.2493 - learning_rate: 0.0010
# Epoch 88/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8861 - loss: 0.2964 - learning_rate: 0.0010
# Epoch 89/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8932 - loss: 0.2727 - learning_rate: 0.0010
# Epoch 90/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8922 - loss: 0.2662 - learning_rate: 0.0010
# Epoch 91/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8917 - loss: 0.2748 - learning_rate: 0.0010
# Epoch 92/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8850 - loss: 0.2664 - learning_rate: 0.0010
# Epoch 93/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8798 - loss: 0.2910 - learning_rate: 0.0010
# Epoch 94/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8887 - loss: 0.2806 - learning_rate: 0.0010
# Epoch 95/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8813 - loss: 0.2840 - learning_rate: 0.0010
# Epoch 96/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8766 - loss: 0.2987 - learning_rate: 0.0010
# Epoch 97/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8844 - loss: 0.2903 - learning_rate: 0.0010
# Epoch 98/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8938 - loss: 0.2692 - learning_rate: 0.0010
# Epoch 99/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8763 - loss: 0.2985 - learning_rate: 0.0010
# Epoch 100/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8819 - loss: 0.2829 - learning_rate: 0.0010

# %%
# 1. Get base predictions on TEST set
test_pred1 = model.predict(X_test)
test_pred2 = model2.predict(X_test)

# 2. Stack them
X_meta_test = np.column_stack((test_pred1, test_pred2))

# 3. Final prediction using the Meta Model
final_predictions = meta_model.predict(X_meta_test)

print("Final Stacked Accuracy:")
meta_model.evaluate(X_meta_test, y_test) # Assuming you have y_test
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Final Stacked Accuracy:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8956 - loss: 0.2489
# [0.2545756697654724, 0.9006211161613464]
